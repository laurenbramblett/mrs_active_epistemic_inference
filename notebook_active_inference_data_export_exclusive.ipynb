# %%
# %reset -f 
# %matplotlib inline
import numpy as np
import os, sys, importlib, itertools
from datetime import datetime
import pandas as pd

# Import the aif module
pwd = os.path.abspath('') + "/"
sys.path.insert(1,pwd + '/aif_catkin_ws/aif_gazebo/scripts/')
import aif_functions_isobeliefs_convergent as aif

importlib.reload(aif)
# Out:
# <module 'aif_functions_isobeliefs_convergent' from 'c:\\Users\\qbr5kx\\OneDrive - University of Virginia\\Desktop\\UVA\\PhD Scratch\\Active_Epistemic_Inference\\aif_multi_robot//aif_catkin_ws/aif_gazebo/scripts\\aif_functions_isobeliefs_convergent.py'>

# %%
# Re-define the environment and simulation parameters here
interactive = True  # Set to True to display the animation in the notebook
args = {}
count = 0; flag_converged = True
draft_results = []
max_iterations = 50
convergence_type = 'exclusive'
list_types = ['A','B']
number_of_heading_options = 8; number_of_velocity_options = 4
env_size = 30  # Environment size
iterations_per_episode = 100  # Number of iterations per episode

while flag_converged and count < max_iterations:
    for use_ep in [True, False]:
        for greedy in [True, False]:
            if greedy and not use_ep:
                continue
            for num_agents in np.arange(2, 6, 1):
                num_goals = num_agents
                # for num_goals in np.arange(2, 6, 1):
                random_seed = count  # Random seed 
                np.random.seed(random_seed)  # Set random seed
                goals = np.random.uniform(1,env_size-1,size=(num_goals, 2))  # Goal positions
                agent_positions = np.hstack((np.random.uniform(0,env_size,size=(num_agents, 2)),np.zeros((num_agents,1))))  # Initial agent positions
                # Set random goals
                args = dict({
                'goals': goals, # Goal positions
                'agent_types': np.random.choice(list_types,num_agents), # Agent types
                'home_base': np.array([0,0]), # Home base position
                'agent_positions': agent_positions, # Initial agent positions
                'velocity_options': np.linspace(0,1,number_of_velocity_options,endpoint=True), # Velocity options
                'num_heading_options': number_of_heading_options, # Number of heading options
                'heading_options': np.linspace(-np.pi,np.pi,number_of_heading_options,endpoint=True),
                'observation_error_std': 0.5, # Observation error standard deviation
                'num_actions': number_of_heading_options*number_of_velocity_options, # Number of actions
                'env_size': env_size, # Environment size
                'max_distance_measure': env_size + 20,
                'max_heading_measure': np.pi, # Maximum heading measure
                'prior': np.ones(goals.shape[0]) / goals.shape[0], # Prior belief
                'use_ep': use_ep, # Use epistemic planning (2nd order reasoning)
                'greedy': greedy, # Use greedy planning
                'horizon': 5, # Horizon for free energy checking
                'mcts_iterations': 100, # Number of MCTS iterations
                'use_mcts': False,
                'use_rhc': False, # Use RHC for planning
                'use_threading': False, #TODO: Implement threading
                'convergence_type': convergence_type, # Convergence type
                'dt': 1.0, # Time step
                })

                # Check convergence for different types of conergence criterion
                if args['convergence_type'] == 'exclusive':
                    tuple_elements = [i for i in range(goals.shape[0])]
                    configurations = list(itertools.permutations(tuple_elements))
                    args['reward_configs'] = configurations # Reward configurations if different goals
                else:
                    args['reward_configs'] = [tuple(np.repeat(i, num_agents)) for i in range(num_goals)]
                

                # print("Initial Prior: ", args['prior'])

                # Run the simulation
                results = aif.run_simulation(args, iterations_per_episode)
                # print("Final Prior: ", prior)
                # print("Agent Types: ", args['agent_types'])

                # energy_results, ending_energy = aif.parse_free_energy_scores(avg_nrg_over_time, num_frames)
                draft_results.append([random_seed, results['converged'], num_goals, num_agents, args['agent_types'], 
                                    use_ep, greedy, results['iteration']])
    print("-------------------")
    print("\rPercentage Complete: ", count/max_iterations*100, "%", end="")
    print("-------------------")
    count += 1

# Save the results
current_time = datetime.now().strftime("%Y%m%d-%H%M%S")
df = pd.DataFrame(draft_results, columns=['seed','converged','num_goals','num_agents','agent_types','use_ep','greedy','num_iters'])    
df.to_csv(pwd + 'data/results_isobeliefs_envSize30_2-5Agents_numGoals2-5_withUncertainty_Exclusive{}.csv'.format(current_time), index=False)
# Out:
# Iteration 100: Agents have selected goals [0, 0]. Execution Time: 0.0s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 1, 1]. Execution Time: 0.0009989738464355469s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 1, 3, 2]. Execution Time: 0.003000974655151367s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 3, 2, 3, 0]. Execution Time: 0.006000041961669922s Agents did not converge to the same goal within the maximum iterations.
# Iteration 11: Agents have selected goals [1, 0]. Execution Time: 0.014009952545166016s Agents have converged to Goal 1 after 11 iterations. Use EP: True
# Iteration 100: Agents have selected goals [2, 1, 1]. Execution Time: 0.04210638999938965s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 1, 3, 2]. Execution Time: 0.07000088691711426s Agents did not converge to the same goal within the maximum iterations.
# Iteration 27: Agents have selected goals [4, 3, 1, 2, 0]. Execution Time: 0.24399995803833008s Agents have converged to Goal 4 after 27 iterations. Use EP: True
# Iteration 11: Agents have selected goals [1, 0]. Execution Time: 0.008005380630493164s Agents have converged to Goal 1 after 11 iterations. Use EP: False
# Iteration 100: Agents have selected goals [1, 1, 1]. Execution Time: 0.015084981918334961s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 3, 0, 3]. Execution Time: 0.0200040340423584s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [4, 0, 3, 0, 0]. Execution Time: 0.03912186622619629s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  0.0 %-------------------
# Iteration 100: Agents have selected goals [1, 1]. Execution Time: 0.0008728504180908203s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 0, 0]. Execution Time: 0.002000570297241211s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 0, 0, 1]. Execution Time: 0.003000020980834961s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 0, 1, 4, 2]. Execution Time: 0.007000446319580078s Agents did not converge to the same goal within the maximum iterations.
# Iteration 43: Agents have selected goals [0, 1]. Execution Time: 0.0159912109375s Agents have converged to Goal 0 after 43 iterations. Use EP: True
# Iteration 20: Agents have selected goals [1, 2, 0]. Execution Time: 0.03212285041809082s Agents have converged to Goal 1 after 20 iterations. Use EP: True
# Iteration 100: Agents have selected goals [0, 0, 0, 0]. Execution Time: 0.07600021362304688s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 0, 0, 0, 0]. Execution Time: 0.2539217472076416s Agents did not converge to the same goal within the maximum iterations.
# Iteration 17: Agents have selected goals [1, 0]. Execution Time: 0.0070002079010009766s Agents have converged to Goal 1 after 17 iterations. Use EP: False
# Iteration 21: Agents have selected goals [1, 2, 0]. Execution Time: 0.014997243881225586s Agents have converged to Goal 1 after 21 iterations. Use EP: False
# Iteration 100: Agents have selected goals [1, 1, 1, 1]. Execution Time: 0.020999670028686523s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 3, 3, 3, 3]. Execution Time: 0.03599429130554199s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  2.0 %-------------------
# Iteration 100: Agents have selected goals [1, 1]. Execution Time: 0.0010039806365966797s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 2, 1]. Execution Time: 0.0009987354278564453s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 1, 3, 3]. Execution Time: 0.0019190311431884766s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 3, 3, 1, 0]. Execution Time: 0.006000041961669922s Agents did not converge to the same goal within the maximum iterations.
# Iteration 23: Agents have selected goals [0, 1]. Execution Time: 0.012980461120605469s Agents have converged to Goal 0 after 23 iterations. Use EP: True
# Iteration 15: Agents have selected goals [2, 0, 1]. Execution Time: 0.03300046920776367s Agents have converged to Goal 2 after 15 iterations. Use EP: True
# Iteration 14: Agents have selected goals [0, 1, 2, 3]. Execution Time: 0.07200264930725098s Agents have converged to Goal 0 after 14 iterations. Use EP: True
# Iteration 21: Agents have selected goals [2, 4, 3, 1, 0]. Execution Time: 0.24500226974487305s Agents have converged to Goal 2 after 21 iterations. Use EP: True
# Iteration 21: Agents have selected goals [0, 1]. Execution Time: 0.0069997310638427734s Agents have converged to Goal 0 after 21 iterations. Use EP: False
# Iteration 15: Agents have selected goals [2, 0, 1]. Execution Time: 0.013002395629882812s Agents have converged to Goal 2 after 15 iterations. Use EP: False
# Iteration 25: Agents have selected goals [0, 2, 1, 3]. Execution Time: 0.018996238708496094s Agents have converged to Goal 0 after 25 iterations. Use EP: False
# Iteration 60: Agents have selected goals [1, 0, 3, 2, 4]. Execution Time: 0.03799891471862793s Agents have converged to Goal 1 after 60 iterations. Use EP: False
# -------------------
# Percentage Complete:  4.0 %-------------------
# Iteration 15: Agents have selected goals [0, 1]. Execution Time: 0.0s Agents have converged to Goal 0 after 15 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 1, 1]. Execution Time: 0.002000093460083008s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 3, 1, 0]. Execution Time: 0.0019867420196533203s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [4, 1, 0, 4, 1]. Execution Time: 0.0060002803802490234s Agents did not converge to the same goal within the maximum iterations.
# Iteration 22: Agents have selected goals [0, 1]. Execution Time: 0.013031005859375s Agents have converged to Goal 0 after 22 iterations. Use EP: True
# Iteration 100: Agents have selected goals [2, 0, 1]. Execution Time: 0.032907962799072266s Agents did not converge to the same goal within the maximum iterations.
# Iteration 18: Agents have selected goals [1, 3, 0, 2]. Execution Time: 0.06999993324279785s Agents have converged to Goal 1 after 18 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 0, 2, 4, 3]. Execution Time: 0.27899813652038574s Agents did not converge to the same goal within the maximum iterations.
# Iteration 26: Agents have selected goals [0, 1]. Execution Time: 0.008000373840332031s Agents have converged to Goal 0 after 26 iterations. Use EP: False
# Iteration 100: Agents have selected goals [2, 1, 0]. Execution Time: 0.015902042388916016s Agents did not converge to the same goal within the maximum iterations.
# Iteration 18: Agents have selected goals [3, 1, 0, 2]. Execution Time: 0.025000333786010742s Agents have converged to Goal 3 after 18 iterations. Use EP: False
# Iteration 100: Agents have selected goals [1, 0, 2, 1, 4]. Execution Time: 0.03800010681152344s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  6.0 %-------------------
# Iteration 100: Agents have selected goals [0, 0]. Execution Time: 0.0009212493896484375s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 2, 2]. Execution Time: 0.0019996166229248047s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 2, 1, 2]. Execution Time: 0.0019812583923339844s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 1, 4, 4, 4]. Execution Time: 0.005995035171508789s Agents did not converge to the same goal within the maximum iterations.
# Iteration 33: Agents have selected goals [1, 0]. Execution Time: 0.012911796569824219s Agents have converged to Goal 1 after 33 iterations. Use EP: True
# Iteration 44: Agents have selected goals [0, 1, 2]. Execution Time: 0.039998531341552734s Agents have converged to Goal 0 after 44 iterations. Use EP: True
# Iteration 35: Agents have selected goals [2, 3, 1, 0]. Execution Time: 0.07399988174438477s Agents have converged to Goal 2 after 35 iterations. Use EP: True
# Iteration 47: Agents have selected goals [3, 1, 0, 2, 4]. Execution Time: 0.24700355529785156s Agents have converged to Goal 3 after 47 iterations. Use EP: True
# Iteration 28: Agents have selected goals [1, 0]. Execution Time: 0.00899958610534668s Agents have converged to Goal 1 after 28 iterations. Use EP: False
# Iteration 44: Agents have selected goals [0, 1, 2]. Execution Time: 0.01300048828125s Agents have converged to Goal 0 after 44 iterations. Use EP: False
# Iteration 100: Agents have selected goals [3, 2, 1, 0]. Execution Time: 0.020999670028686523s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 2, 4, 1, 2]. Execution Time: 0.03800082206726074s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  8.0 %-------------------
# Iteration 100: Agents have selected goals [0, 0]. Execution Time: 0.0009999275207519531s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 2, 0]. Execution Time: 0.0009999275207519531s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 0, 2, 3]. Execution Time: 0.002000093460083008s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 4, 3, 4, 3]. Execution Time: 0.004999876022338867s Agents did not converge to the same goal within the maximum iterations.
# Iteration 79: Agents have selected goals [0, 1]. Execution Time: 0.014091730117797852s Agents have converged to Goal 0 after 79 iterations. Use EP: True
# Iteration 32: Agents have selected goals [1, 2, 0]. Execution Time: 0.03400063514709473s Agents have converged to Goal 1 after 32 iterations. Use EP: True
# Iteration 100: Agents have selected goals [0, 1, 2, 2]. Execution Time: 0.08000063896179199s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 4, 3, 4, 2]. Execution Time: 0.24799823760986328s Agents did not converge to the same goal within the maximum iterations.
# Iteration 72: Agents have selected goals [0, 1]. Execution Time: 0.006997346878051758s Agents have converged to Goal 0 after 72 iterations. Use EP: False
# Iteration 84: Agents have selected goals [1, 0, 2]. Execution Time: 0.013000011444091797s Agents have converged to Goal 1 after 84 iterations. Use EP: False
# Iteration 100: Agents have selected goals [2, 1, 3, 2]. Execution Time: 0.020910024642944336s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 2, 3, 2, 4]. Execution Time: 0.03890728950500488s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  10.0 %-------------------
# Iteration 100: Agents have selected goals [0, 0]. Execution Time: 0.0009999275207519531s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 2, 2]. Execution Time: 0.0010843276977539062s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 3, 3, 3]. Execution Time: 0.0019998550415039062s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [4, 3, 4, 0, 0]. Execution Time: 0.00599980354309082s Agents did not converge to the same goal within the maximum iterations.
# Iteration 34: Agents have selected goals [0, 1]. Execution Time: 0.013052701950073242s Agents have converged to Goal 0 after 34 iterations. Use EP: True
# Iteration 39: Agents have selected goals [1, 0, 2]. Execution Time: 0.03300023078918457s Agents have converged to Goal 1 after 39 iterations. Use EP: True
# Iteration 32: Agents have selected goals [2, 3, 1, 0]. Execution Time: 0.07508134841918945s Agents have converged to Goal 2 after 32 iterations. Use EP: True
# Iteration 42: Agents have selected goals [4, 3, 2, 0, 1]. Execution Time: 0.25400257110595703s Agents have converged to Goal 4 after 42 iterations. Use EP: True
# Iteration 34: Agents have selected goals [1, 0]. Execution Time: 0.008997917175292969s Agents have converged to Goal 1 after 34 iterations. Use EP: False
# Iteration 29: Agents have selected goals [1, 2, 0]. Execution Time: 0.01399993896484375s Agents have converged to Goal 1 after 29 iterations. Use EP: False
# Iteration 32: Agents have selected goals [2, 3, 1, 0]. Execution Time: 0.021020889282226562s Agents have converged to Goal 2 after 32 iterations. Use EP: False
# Iteration 42: Agents have selected goals [4, 3, 2, 0, 1]. Execution Time: 0.038002729415893555s Agents have converged to Goal 4 after 42 iterations. Use EP: False
# -------------------
# Percentage Complete:  12.0 %-------------------
# Iteration 100: Agents have selected goals [1, 1]. Execution Time: 0.0010085105895996094s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 1, 1]. Execution Time: 0.0010063648223876953s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 1, 3, 0]. Execution Time: 0.002000093460083008s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 3, 0, 4, 3]. Execution Time: 0.006000041961669922s Agents did not converge to the same goal within the maximum iterations.
# Iteration 52: Agents have selected goals [1, 0]. Execution Time: 0.014000415802001953s Agents have converged to Goal 1 after 52 iterations. Use EP: True
# Iteration 31: Agents have selected goals [2, 0, 1]. Execution Time: 0.03300023078918457s Agents have converged to Goal 2 after 31 iterations. Use EP: True
# Iteration 16: Agents have selected goals [1, 2, 3, 0]. Execution Time: 0.07599711418151855s Agents have converged to Goal 1 after 16 iterations. Use EP: True
# Iteration 100: Agents have selected goals [4, 4, 0, 3, 2]. Execution Time: 0.24593234062194824s Agents did not converge to the same goal within the maximum iterations.
# Iteration 52: Agents have selected goals [1, 0]. Execution Time: 0.0069997310638427734s Agents have converged to Goal 1 after 52 iterations. Use EP: False
# Iteration 31: Agents have selected goals [2, 0, 1]. Execution Time: 0.012999534606933594s Agents have converged to Goal 2 after 31 iterations. Use EP: False
# Iteration 100: Agents have selected goals [2, 1, 1, 0]. Execution Time: 0.021900177001953125s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 3, 0, 3, 2]. Execution Time: 0.03699636459350586s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  14.000000000000002 %-------------------
# Iteration 100: Agents have selected goals [1, 1]. Execution Time: 0.0009996891021728516s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 1, 1]. Execution Time: 0.0010004043579101562s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 3, 1, 3]. Execution Time: 0.0030024051666259766s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [4, 1, 4, 4, 2]. Execution Time: 0.00599980354309082s Agents did not converge to the same goal within the maximum iterations.
# Iteration 96: Agents have selected goals [0, 1]. Execution Time: 0.01399993896484375s Agents have converged to Goal 0 after 96 iterations. Use EP: True
# Iteration 20: Agents have selected goals [2, 1, 0]. Execution Time: 0.04299521446228027s Agents have converged to Goal 2 after 20 iterations. Use EP: True
# Iteration 100: Agents have selected goals [3, 1, 0, 2]. Execution Time: 0.07497429847717285s Agents did not converge to the same goal within the maximum iterations.
# Iteration 26: Agents have selected goals [4, 1, 3, 0, 2]. Execution Time: 0.25099992752075195s Agents have converged to Goal 4 after 26 iterations. Use EP: True
# Iteration 34: Agents have selected goals [1, 0]. Execution Time: 0.008001565933227539s Agents have converged to Goal 1 after 34 iterations. Use EP: False
# Iteration 20: Agents have selected goals [2, 1, 0]. Execution Time: 0.012999534606933594s Agents have converged to Goal 2 after 20 iterations. Use EP: False
# Iteration 100: Agents have selected goals [2, 1, 2, 2]. Execution Time: 0.021000146865844727s Agents did not converge to the same goal within the maximum iterations.
# Iteration 81: Agents have selected goals [3, 0, 2, 1, 4]. Execution Time: 0.03800559043884277s Agents have converged to Goal 3 after 81 iterations. Use EP: False
# -------------------
# Percentage Complete:  16.0 %-------------------
# Iteration 12: Agents have selected goals [0, 1]. Execution Time: 0.0s Agents have converged to Goal 0 after 12 iterations. Use EP: True
# Iteration 15: Agents have selected goals [1, 2, 0]. Execution Time: 0.0030007362365722656s Agents have converged to Goal 1 after 15 iterations. Use EP: True
# Iteration 17: Agents have selected goals [2, 0, 1, 3]. Execution Time: 0.0039598941802978516s Agents have converged to Goal 2 after 17 iterations. Use EP: True
# Iteration 100: Agents have selected goals [0, 1, 3, 3, 3]. Execution Time: 0.007002592086791992s Agents did not converge to the same goal within the maximum iterations.
# Iteration 13: Agents have selected goals [0, 1]. Execution Time: 0.014003276824951172s Agents have converged to Goal 0 after 13 iterations. Use EP: True
# Iteration 18: Agents have selected goals [1, 2, 0]. Execution Time: 0.03499746322631836s Agents have converged to Goal 1 after 18 iterations. Use EP: True
# Iteration 19: Agents have selected goals [2, 0, 1, 3]. Execution Time: 0.07200169563293457s Agents have converged to Goal 2 after 19 iterations. Use EP: True
# Iteration 100: Agents have selected goals [4, 1, 4, 4, 0]. Execution Time: 0.2500038146972656s Agents did not converge to the same goal within the maximum iterations.
# Iteration 13: Agents have selected goals [0, 1]. Execution Time: 0.006999015808105469s Agents have converged to Goal 0 after 13 iterations. Use EP: False
# Iteration 18: Agents have selected goals [1, 2, 0]. Execution Time: 0.014000415802001953s Agents have converged to Goal 1 after 18 iterations. Use EP: False
# Iteration 19: Agents have selected goals [2, 0, 1, 3]. Execution Time: 0.01999521255493164s Agents have converged to Goal 2 after 19 iterations. Use EP: False
# Iteration 100: Agents have selected goals [2, 1, 2, 4, 0]. Execution Time: 0.04035139083862305s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  18.0 %-------------------
# Iteration 16: Agents have selected goals [0, 1]. Execution Time: 0.0010128021240234375s Agents have converged to Goal 0 after 16 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 2, 1]. Execution Time: 0.0010001659393310547s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 1, 3, 1]. Execution Time: 0.002050161361694336s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 3, 1, 2, 1]. Execution Time: 0.006999969482421875s Agents did not converge to the same goal within the maximum iterations.
# Iteration 19: Agents have selected goals [0, 1]. Execution Time: 0.015000581741333008s Agents have converged to Goal 0 after 19 iterations. Use EP: True
# Iteration 100: Agents have selected goals [2, 2, 1]. Execution Time: 0.03500008583068848s Agents did not converge to the same goal within the maximum iterations.
# Iteration 37: Agents have selected goals [2, 0, 3, 1]. Execution Time: 0.07594132423400879s Agents have converged to Goal 2 after 37 iterations. Use EP: True
# Iteration 100: Agents have selected goals [0, 0, 0, 0, 1]. Execution Time: 0.2990844249725342s Agents did not converge to the same goal within the maximum iterations.
# Iteration 19: Agents have selected goals [0, 1]. Execution Time: 0.007999897003173828s Agents have converged to Goal 0 after 19 iterations. Use EP: False
# Iteration 100: Agents have selected goals [2, 1, 2]. Execution Time: 0.013000011444091797s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 1, 3, 1]. Execution Time: 0.02100086212158203s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [4, 4, 2, 4, 2]. Execution Time: 0.03799724578857422s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  20.0 %-------------------
# Iteration 17: Agents have selected goals [1, 0]. Execution Time: 0.001003265380859375s Agents have converged to Goal 1 after 17 iterations. Use EP: True
# Iteration 100: Agents have selected goals [2, 1, 2]. Execution Time: 0.002094268798828125s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 2, 1, 3]. Execution Time: 0.0020003318786621094s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 4, 3, 0, 0]. Execution Time: 0.004999876022338867s Agents did not converge to the same goal within the maximum iterations.
# Iteration 22: Agents have selected goals [1, 0]. Execution Time: 0.02200150489807129s Agents have converged to Goal 1 after 22 iterations. Use EP: True
# Iteration 23: Agents have selected goals [0, 1, 2]. Execution Time: 0.03299283981323242s Agents have converged to Goal 0 after 23 iterations. Use EP: True
# Iteration 26: Agents have selected goals [2, 0, 1, 3]. Execution Time: 0.07099771499633789s Agents have converged to Goal 2 after 26 iterations. Use EP: True
# Iteration 100: Agents have selected goals [2, 4, 1, 3, 0]. Execution Time: 0.25100040435791016s Agents did not converge to the same goal within the maximum iterations.
# Iteration 21: Agents have selected goals [1, 0]. Execution Time: 0.007999897003173828s Agents have converged to Goal 1 after 21 iterations. Use EP: False
# Iteration 100: Agents have selected goals [0, 0, 0]. Execution Time: 0.012987375259399414s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 2, 2, 3]. Execution Time: 0.03300142288208008s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [4, 4, 4, 4, 4]. Execution Time: 0.037912845611572266s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  22.0 %-------------------
# Iteration 27: Agents have selected goals [0, 1]. Execution Time: 0.0s Agents have converged to Goal 0 after 27 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 1, 1]. Execution Time: 0.0009980201721191406s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 1, 1, 0]. Execution Time: 0.0030143260955810547s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 4, 0, 1, 3]. Execution Time: 0.004999637603759766s Agents did not converge to the same goal within the maximum iterations.
# Iteration 29: Agents have selected goals [0, 1]. Execution Time: 0.01708984375s Agents have converged to Goal 0 after 29 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 1, 1]. Execution Time: 0.034989356994628906s Agents did not converge to the same goal within the maximum iterations.
# Iteration 43: Agents have selected goals [3, 1, 2, 0]. Execution Time: 0.08100032806396484s Agents have converged to Goal 3 after 43 iterations. Use EP: True
# Iteration 28: Agents have selected goals [0, 4, 2, 1, 3]. Execution Time: 0.24889492988586426s Agents have converged to Goal 0 after 28 iterations. Use EP: True
# Iteration 34: Agents have selected goals [0, 1]. Execution Time: 0.007998228073120117s Agents have converged to Goal 0 after 34 iterations. Use EP: False
# Iteration 100: Agents have selected goals [1, 1, 0]. Execution Time: 0.015999794006347656s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 1, 1, 2]. Execution Time: 0.02000284194946289s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 3, 4, 4, 4]. Execution Time: 0.037999629974365234s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  24.0 %-------------------
# Iteration 12: Agents have selected goals [0, 1]. Execution Time: 0.0s Agents have converged to Goal 0 after 12 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 1, 0]. Execution Time: 0.0009722709655761719s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 0, 3, 3]. Execution Time: 0.002119779586791992s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [4, 3, 3, 0, 4]. Execution Time: 0.00599980354309082s Agents did not converge to the same goal within the maximum iterations.
# Iteration 12: Agents have selected goals [0, 1]. Execution Time: 0.014018535614013672s Agents have converged to Goal 0 after 12 iterations. Use EP: True
# Iteration 31: Agents have selected goals [2, 1, 0]. Execution Time: 0.034912824630737305s Agents have converged to Goal 2 after 31 iterations. Use EP: True
# Iteration 41: Agents have selected goals [3, 0, 1, 2]. Execution Time: 0.07399654388427734s Agents have converged to Goal 3 after 41 iterations. Use EP: True
# Iteration 65: Agents have selected goals [2, 1, 4, 0, 3]. Execution Time: 0.2509040832519531s Agents have converged to Goal 2 after 65 iterations. Use EP: True
# Iteration 15: Agents have selected goals [0, 1]. Execution Time: 0.008010149002075195s Agents have converged to Goal 0 after 15 iterations. Use EP: False
# Iteration 100: Agents have selected goals [1, 1, 1]. Execution Time: 0.013063192367553711s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 0, 1, 2]. Execution Time: 0.020954370498657227s Agents have converged to Goal 3 after 100 iterations. Use EP: False
# Iteration 100: Agents have selected goals [0, 1, 3, 3, 4]. Execution Time: 0.04801583290100098s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  26.0 %-------------------
# Iteration 16: Agents have selected goals [0, 1]. Execution Time: 0.0s Agents have converged to Goal 0 after 16 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 1, 1]. Execution Time: 0.002103090286254883s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 3, 1, 3]. Execution Time: 0.002999544143676758s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [4, 4, 4, 1, 0]. Execution Time: 0.006002187728881836s Agents did not converge to the same goal within the maximum iterations.
# Iteration 19: Agents have selected goals [0, 1]. Execution Time: 0.013988018035888672s Agents have converged to Goal 0 after 19 iterations. Use EP: True
# Iteration 35: Agents have selected goals [0, 2, 1]. Execution Time: 0.03399848937988281s Agents have converged to Goal 0 after 35 iterations. Use EP: True
# Iteration 100: Agents have selected goals [3, 0, 3, 1]. Execution Time: 0.07392692565917969s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 1, 3, 0, 2]. Execution Time: 0.2499983310699463s Agents did not converge to the same goal within the maximum iterations.
# Iteration 21: Agents have selected goals [0, 1]. Execution Time: 0.0069997310638427734s Agents have converged to Goal 0 after 21 iterations. Use EP: False
# Iteration 34: Agents have selected goals [0, 2, 1]. Execution Time: 0.013905763626098633s Agents have converged to Goal 0 after 34 iterations. Use EP: False
# Iteration 100: Agents have selected goals [3, 0, 3, 3]. Execution Time: 0.023997783660888672s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 1, 3, 3, 2]. Execution Time: 0.03799700736999512s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  28.000000000000004 %-------------------
# Iteration 100: Agents have selected goals [1, 1]. Execution Time: 0.0009999275207519531s Agents did not converge to the same goal within the maximum iterations.
# Iteration 10: Agents have selected goals [2, 1, 0]. Execution Time: 0.0010001659393310547s Agents have converged to Goal 2 after 10 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 0, 2, 0]. Execution Time: 0.002986907958984375s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 2, 0, 4, 4]. Execution Time: 0.006092548370361328s Agents did not converge to the same goal within the maximum iterations.
# Iteration 27: Agents have selected goals [0, 1]. Execution Time: 0.014884233474731445s Agents have converged to Goal 0 after 27 iterations. Use EP: True
# Iteration 100: Agents have selected goals [2, 2, 2]. Execution Time: 0.03499746322631836s Agents did not converge to the same goal within the maximum iterations.
# Iteration 23: Agents have selected goals [1, 0, 2, 3]. Execution Time: 0.07498836517333984s Agents have converged to Goal 1 after 23 iterations. Use EP: True
# Iteration 44: Agents have selected goals [3, 2, 0, 4, 1]. Execution Time: 0.2549910545349121s Agents have converged to Goal 3 after 44 iterations. Use EP: True
# Iteration 21: Agents have selected goals [1, 0]. Execution Time: 0.007999897003173828s Agents have converged to Goal 1 after 21 iterations. Use EP: False
# Iteration 100: Agents have selected goals [0, 0, 0]. Execution Time: 0.014026165008544922s Agents did not converge to the same goal within the maximum iterations.
# Iteration 25: Agents have selected goals [1, 3, 2, 0]. Execution Time: 0.01999974250793457s Agents have converged to Goal 1 after 25 iterations. Use EP: False
# Iteration 100: Agents have selected goals [3, 2, 0, 3, 1]. Execution Time: 0.038001060485839844s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  30.0 %-------------------
# Iteration 100: Agents have selected goals [1, 1]. Execution Time: 0.0s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 0, 1]. Execution Time: 0.000995635986328125s Agents did not converge to the same goal within the maximum iterations.
# Iteration 16: Agents have selected goals [0, 1, 3, 2]. Execution Time: 0.001999378204345703s Agents have converged to Goal 0 after 16 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 3, 2, 3, 0]. Execution Time: 0.005998849868774414s Agents did not converge to the same goal within the maximum iterations.
# Iteration 13: Agents have selected goals [0, 1]. Execution Time: 0.019999980926513672s Agents have converged to Goal 0 after 13 iterations. Use EP: True
# Iteration 17: Agents have selected goals [2, 0, 1]. Execution Time: 0.03391456604003906s Agents have converged to Goal 2 after 17 iterations. Use EP: True
# Iteration 17: Agents have selected goals [0, 1, 3, 2]. Execution Time: 0.07399678230285645s Agents have converged to Goal 0 after 17 iterations. Use EP: True
# Iteration 33: Agents have selected goals [1, 3, 2, 4, 0]. Execution Time: 0.2489159107208252s Agents have converged to Goal 1 after 33 iterations. Use EP: True
# Iteration 13: Agents have selected goals [0, 1]. Execution Time: 0.007981061935424805s Agents have converged to Goal 0 after 13 iterations. Use EP: False
# Iteration 33: Agents have selected goals [1, 0, 2]. Execution Time: 0.013000965118408203s Agents have converged to Goal 1 after 33 iterations. Use EP: False
# Iteration 100: Agents have selected goals [0, 1, 3, 2]. Execution Time: 0.021001577377319336s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 2, 0, 4, 2]. Execution Time: 0.037999868392944336s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  32.0 %-------------------
# Iteration 100: Agents have selected goals [0, 0]. Execution Time: 0.0009999275207519531s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 1, 2]. Execution Time: 0.0009920597076416016s Agents did not converge to the same goal within the maximum iterations.
# Iteration 21: Agents have selected goals [1, 3, 2, 0]. Execution Time: 0.002020120620727539s Agents have converged to Goal 1 after 21 iterations. Use EP: True
# Iteration 100: Agents have selected goals [3, 2, 0, 3, 0]. Execution Time: 0.006000041961669922s Agents did not converge to the same goal within the maximum iterations.
# Iteration 53: Agents have selected goals [1, 0]. Execution Time: 0.014000177383422852s Agents have converged to Goal 1 after 53 iterations. Use EP: True
# Iteration 35: Agents have selected goals [2, 0, 1]. Execution Time: 0.03399801254272461s Agents have converged to Goal 2 after 35 iterations. Use EP: True
# Iteration 23: Agents have selected goals [1, 3, 2, 0]. Execution Time: 0.0720977783203125s Agents have converged to Goal 1 after 23 iterations. Use EP: True
# Iteration 34: Agents have selected goals [1, 2, 4, 3, 0]. Execution Time: 0.25499987602233887s Agents have converged to Goal 1 after 34 iterations. Use EP: True
# Iteration 53: Agents have selected goals [1, 0]. Execution Time: 0.008000373840332031s Agents have converged to Goal 1 after 53 iterations. Use EP: False
# Iteration 35: Agents have selected goals [2, 0, 1]. Execution Time: 0.01599884033203125s Agents have converged to Goal 2 after 35 iterations. Use EP: False
# Iteration 100: Agents have selected goals [1, 0, 2, 0]. Execution Time: 0.02099919319152832s Agents did not converge to the same goal within the maximum iterations.
# Iteration 62: Agents have selected goals [1, 2, 4, 3, 0]. Execution Time: 0.03800010681152344s Agents have converged to Goal 1 after 62 iterations. Use EP: False
# -------------------
# Percentage Complete:  34.0 %-------------------
# Iteration 100: Agents have selected goals [0, 0]. Execution Time: 0.0s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 0, 2]. Execution Time: 0.0010035037994384766s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 3, 1, 0]. Execution Time: 0.001997709274291992s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 1, 4, 3, 0]. Execution Time: 0.00599980354309082s Agents did not converge to the same goal within the maximum iterations.
# Iteration 33: Agents have selected goals [1, 0]. Execution Time: 0.013005256652832031s Agents have converged to Goal 1 after 33 iterations. Use EP: True
# Iteration 31: Agents have selected goals [0, 1, 2]. Execution Time: 0.03493475914001465s Agents have converged to Goal 0 after 31 iterations. Use EP: True
# Iteration 42: Agents have selected goals [2, 3, 1, 0]. Execution Time: 0.0729990005493164s Agents have converged to Goal 2 after 42 iterations. Use EP: True
# Iteration 100: Agents have selected goals [0, 1, 4, 2, 0]. Execution Time: 0.2539198398590088s Agents did not converge to the same goal within the maximum iterations.
# Iteration 33: Agents have selected goals [1, 0]. Execution Time: 0.006906032562255859s Agents have converged to Goal 1 after 33 iterations. Use EP: False
# Iteration 31: Agents have selected goals [2, 1, 0]. Execution Time: 0.015999794006347656s Agents have converged to Goal 2 after 31 iterations. Use EP: False
# Iteration 100: Agents have selected goals [3, 0, 1, 0]. Execution Time: 0.021009206771850586s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 2, 4, 2, 3]. Execution Time: 0.03999972343444824s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  36.0 %-------------------
# Iteration 19: Agents have selected goals [1, 0]. Execution Time: 0.0010004043579101562s Agents have converged to Goal 1 after 19 iterations. Use EP: True
# Iteration 100: Agents have selected goals [0, 2, 0]. Execution Time: 0.0018956661224365234s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 0, 2, 0]. Execution Time: 0.0019981861114501953s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 2, 0, 0, 0]. Execution Time: 0.006000041961669922s Agents did not converge to the same goal within the maximum iterations.
# Iteration 26: Agents have selected goals [1, 0]. Execution Time: 0.01700139045715332s Agents have converged to Goal 1 after 26 iterations. Use EP: True
# Iteration 100: Agents have selected goals [0, 1, 1]. Execution Time: 0.03391456604003906s Agents did not converge to the same goal within the maximum iterations.
# Iteration 16: Agents have selected goals [3, 0, 2, 1]. Execution Time: 0.07209277153015137s Agents have converged to Goal 3 after 16 iterations. Use EP: True
# Iteration 27: Agents have selected goals [4, 2, 1, 0, 3]. Execution Time: 0.24899888038635254s Agents have converged to Goal 4 after 27 iterations. Use EP: True
# Iteration 26: Agents have selected goals [1, 0]. Execution Time: 0.007976770401000977s Agents have converged to Goal 1 after 26 iterations. Use EP: False
# Iteration 100: Agents have selected goals [0, 0, 0]. Execution Time: 0.016002416610717773s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 3, 3, 1]. Execution Time: 0.02100515365600586s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [4, 2, 3, 3, 3]. Execution Time: 0.03790116310119629s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  38.0 %-------------------
# Iteration 100: Agents have selected goals [0, 0]. Execution Time: 0.0009989738464355469s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 1, 2]. Execution Time: 0.0019953250885009766s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 2, 1, 3]. Execution Time: 0.002000570297241211s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 1, 4, 2, 3]. Execution Time: 0.007001399993896484s Agents did not converge to the same goal within the maximum iterations.
# Iteration 35: Agents have selected goals [0, 1]. Execution Time: 0.015002012252807617s Agents have converged to Goal 0 after 35 iterations. Use EP: True
# Iteration 31: Agents have selected goals [0, 1, 2]. Execution Time: 0.035997629165649414s Agents have converged to Goal 0 after 31 iterations. Use EP: True
# Iteration 35: Agents have selected goals [0, 2, 1, 3]. Execution Time: 0.07599925994873047s Agents have converged to Goal 0 after 35 iterations. Use EP: True
# Iteration 100: Agents have selected goals [3, 3, 3, 3, 3]. Execution Time: 0.24811530113220215s Agents did not converge to the same goal within the maximum iterations.
# Iteration 35: Agents have selected goals [0, 1]. Execution Time: 0.008082866668701172s Agents have converged to Goal 0 after 35 iterations. Use EP: False
# Iteration 31: Agents have selected goals [0, 1, 2]. Execution Time: 0.013000249862670898s Agents have converged to Goal 0 after 31 iterations. Use EP: False
# Iteration 100: Agents have selected goals [1, 2, 3, 3]. Execution Time: 0.019999980926513672s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 3, 3, 3, 3]. Execution Time: 0.039002418518066406s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  40.0 %-------------------
# Iteration 100: Agents have selected goals [0, 0]. Execution Time: 0.0009472370147705078s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 0, 0]. Execution Time: 0.0010006427764892578s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 3, 2, 3]. Execution Time: 0.0020096302032470703s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 2, 3, 3, 1]. Execution Time: 0.007999897003173828s Agents did not converge to the same goal within the maximum iterations.
# Iteration 20: Agents have selected goals [1, 0]. Execution Time: 0.013999462127685547s Agents have converged to Goal 1 after 20 iterations. Use EP: True
# Iteration 39: Agents have selected goals [1, 2, 0]. Execution Time: 0.03399658203125s Agents have converged to Goal 1 after 39 iterations. Use EP: True
# Iteration 42: Agents have selected goals [3, 0, 2, 1]. Execution Time: 0.07200217247009277s Agents have converged to Goal 3 after 42 iterations. Use EP: True
# Iteration 28: Agents have selected goals [0, 2, 4, 3, 1]. Execution Time: 0.2590000629425049s Agents have converged to Goal 0 after 28 iterations. Use EP: True
# Iteration 24: Agents have selected goals [1, 0]. Execution Time: 0.008000373840332031s Agents have converged to Goal 1 after 24 iterations. Use EP: False
# Iteration 35: Agents have selected goals [2, 1, 0]. Execution Time: 0.013031482696533203s Agents have converged to Goal 2 after 35 iterations. Use EP: False
# Iteration 100: Agents have selected goals [3, 3, 3, 1]. Execution Time: 0.020999670028686523s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 2, 4, 3, 0]. Execution Time: 0.04100298881530762s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  42.0 %-------------------
# Iteration 9: Agents have selected goals [0, 1]. Execution Time: 0.0009999275207519531s Agents have converged to Goal 0 after 9 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 1, 0]. Execution Time: 0.0010001659393310547s Agents did not converge to the same goal within the maximum iterations.
# Iteration 15: Agents have selected goals [3, 0, 1, 2]. Execution Time: 0.002035379409790039s Agents have converged to Goal 3 after 15 iterations. Use EP: True
# Iteration 100: Agents have selected goals [0, 1, 2, 1, 0]. Execution Time: 0.006000518798828125s Agents did not converge to the same goal within the maximum iterations.
# Iteration 12: Agents have selected goals [0, 1]. Execution Time: 0.014003753662109375s Agents have converged to Goal 0 after 12 iterations. Use EP: True
# Iteration 14: Agents have selected goals [2, 1, 0]. Execution Time: 0.0339655876159668s Agents have converged to Goal 2 after 14 iterations. Use EP: True
# Iteration 19: Agents have selected goals [3, 0, 1, 2]. Execution Time: 0.07391166687011719s Agents have converged to Goal 3 after 19 iterations. Use EP: True
# Iteration 71: Agents have selected goals [0, 4, 2, 3, 1]. Execution Time: 0.25600099563598633s Agents have converged to Goal 0 after 71 iterations. Use EP: True
# Iteration 12: Agents have selected goals [0, 1]. Execution Time: 0.007004261016845703s Agents have converged to Goal 0 after 12 iterations. Use EP: False
# Iteration 14: Agents have selected goals [2, 1, 0]. Execution Time: 0.013000011444091797s Agents have converged to Goal 2 after 14 iterations. Use EP: False
# Iteration 100: Agents have selected goals [2, 3, 1, 3]. Execution Time: 0.021083593368530273s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 3, 3, 3, 2]. Execution Time: 0.038105010986328125s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  44.0 %-------------------
# Iteration 20: Agents have selected goals [0, 1]. Execution Time: 0.0009815692901611328s Agents have converged to Goal 0 after 20 iterations. Use EP: True
# Iteration 100: Agents have selected goals [2, 1, 2]. Execution Time: 0.0008959770202636719s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 2, 1, 0]. Execution Time: 0.002000093460083008s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 1, 0, 1, 3]. Execution Time: 0.005995750427246094s Agents did not converge to the same goal within the maximum iterations.
# Iteration 28: Agents have selected goals [0, 1]. Execution Time: 0.017002582550048828s Agents have converged to Goal 0 after 28 iterations. Use EP: True
# Iteration 26: Agents have selected goals [2, 1, 0]. Execution Time: 0.033972978591918945s Agents have converged to Goal 2 after 26 iterations. Use EP: True
# Iteration 100: Agents have selected goals [2, 2, 2, 2]. Execution Time: 0.07299184799194336s Agents did not converge to the same goal within the maximum iterations.
# Iteration 22: Agents have selected goals [2, 1, 0, 4, 3]. Execution Time: 0.24791979789733887s Agents have converged to Goal 2 after 22 iterations. Use EP: True
# Iteration 28: Agents have selected goals [0, 1]. Execution Time: 0.009000062942504883s Agents have converged to Goal 0 after 28 iterations. Use EP: False
# Iteration 100: Agents have selected goals [2, 2, 0]. Execution Time: 0.014000177383422852s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 2, 2, 2]. Execution Time: 0.02099895477294922s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 2, 2, 1, 2]. Execution Time: 0.037999868392944336s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  46.0 %-------------------
# ...
# Iteration 100: Agents have selected goals [0, 1, 0]. Execution Time: 0.0009987354278564453s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 3, 1, 2]. Execution Time: 0.0019998550415039062s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 1, 2, 4, 2]. Execution Time: 0.00600743293762207s Agents did not converge to the same goal within the maximum iterations.
# Iteration 28: Agents have selected goals [1, 0]. Execution Time: 0.013068199157714844s Agents have converged to Goal 1 after 28 iterations. Use EP: True
# Iteration 100: Agents have selected goals [0, 0, 0]. Execution Time: 0.03901958465576172s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 2, 2, 1]. Execution Time: 0.07708263397216797s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 1, 2, 0, 2]. Execution Time: 0.2508845329284668s Agents did not converge to the same goal within the maximum iterations.
# Iteration 31: Agents have selected goals [1, 0]. Execution Time: 0.008002281188964844s Agents have converged to Goal 1 after 31 iterations. Use EP: False
# Iteration 100: Agents have selected goals [1, 0, 0]. Execution Time: 0.015000343322753906s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 2, 2, 1]. Execution Time: 0.026081323623657227s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [3, 1, 0, 0, 3]. Execution Time: 0.04200458526611328s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  84.0 %-------------------
# Iteration 100: Agents have selected goals [0, 0]. Execution Time: 0.0009953975677490234s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 0, 2]. Execution Time: 0.0009999275207519531s Agents did not converge to the same goal within the maximum iterations.
# Iteration 14: Agents have selected goals [0, 2, 1, 3]. Execution Time: 0.0030024051666259766s Agents have converged to Goal 0 after 14 iterations. Use EP: True
# Iteration 100: Agents have selected goals [2, 1, 3, 1, 4]. Execution Time: 0.004985809326171875s Agents did not converge to the same goal within the maximum iterations.
# Iteration 28: Agents have selected goals [0, 1]. Execution Time: 0.014025688171386719s Agents have converged to Goal 0 after 28 iterations. Use EP: True
# Iteration 31: Agents have selected goals [1, 0, 2]. Execution Time: 0.03899955749511719s Agents have converged to Goal 1 after 31 iterations. Use EP: True
# Iteration 31: Agents have selected goals [0, 2, 1, 3]. Execution Time: 0.07500123977661133s Agents have converged to Goal 0 after 31 iterations. Use EP: True
# Iteration 16: Agents have selected goals [2, 1, 3, 0, 4]. Execution Time: 0.29709577560424805s Agents have converged to Goal 2 after 16 iterations. Use EP: True
# Iteration 25: Agents have selected goals [0, 1]. Execution Time: 0.007999658584594727s Agents have converged to Goal 0 after 25 iterations. Use EP: False
# Iteration 31: Agents have selected goals [1, 0, 2]. Execution Time: 0.016999244689941406s Agents have converged to Goal 1 after 31 iterations. Use EP: False
# Iteration 100: Agents have selected goals [0, 2, 1, 3]. Execution Time: 0.02200007438659668s Agents did not converge to the same goal within the maximum iterations.
# Iteration 33: Agents have selected goals [2, 0, 3, 1, 4]. Execution Time: 0.04101276397705078s Agents have converged to Goal 2 after 33 iterations. Use EP: False
# -------------------
# Percentage Complete:  86.0 %-------------------
# Iteration 100: Agents have selected goals [1, 1]. Execution Time: 0.0009453296661376953s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 2, 1]. Execution Time: 0.0019996166229248047s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 1, 3, 2]. Execution Time: 0.003000497817993164s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 3, 2, 4, 1]. Execution Time: 0.006002187728881836s Agents did not converge to the same goal within the maximum iterations.
# Iteration 25: Agents have selected goals [1, 0]. Execution Time: 0.013999700546264648s Agents have converged to Goal 1 after 25 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 2, 1]. Execution Time: 0.03299736976623535s Agents did not converge to the same goal within the maximum iterations.
# Iteration 21: Agents have selected goals [3, 1, 0, 2]. Execution Time: 0.07588458061218262s Agents have converged to Goal 3 after 21 iterations. Use EP: True
# Iteration 21: Agents have selected goals [1, 3, 2, 4, 0]. Execution Time: 0.2520017623901367s Agents have converged to Goal 1 after 21 iterations. Use EP: True
# Iteration 21: Agents have selected goals [1, 0]. Execution Time: 0.0070002079010009766s Agents have converged to Goal 1 after 21 iterations. Use EP: False
# Iteration 100: Agents have selected goals [2, 2, 2]. Execution Time: 0.013934135437011719s Agents did not converge to the same goal within the maximum iterations.
# Iteration 20: Agents have selected goals [3, 1, 0, 2]. Execution Time: 0.02109217643737793s Agents have converged to Goal 3 after 20 iterations. Use EP: False
# Iteration 100: Agents have selected goals [2, 1, 3, 4, 0]. Execution Time: 0.03899884223937988s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  88.0 %-------------------
# Iteration 100: Agents have selected goals [1, 1]. Execution Time: 0.0010035037994384766s Agents did not converge to the same goal within the maximum iterations.
# Iteration 14: Agents have selected goals [1, 2, 0]. Execution Time: 0.001898050308227539s Agents have converged to Goal 1 after 14 iterations. Use EP: True
# Iteration 100: Agents have selected goals [2, 0, 0, 2]. Execution Time: 0.0020003318786621094s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 0, 2, 0, 2]. Execution Time: 0.006997108459472656s Agents did not converge to the same goal within the maximum iterations.
# Iteration 20: Agents have selected goals [0, 1]. Execution Time: 0.013964414596557617s Agents have converged to Goal 0 after 20 iterations. Use EP: True
# Iteration 15: Agents have selected goals [1, 2, 0]. Execution Time: 0.03309154510498047s Agents have converged to Goal 1 after 15 iterations. Use EP: True
# Iteration 22: Agents have selected goals [3, 2, 0, 1]. Execution Time: 0.07400083541870117s Agents have converged to Goal 3 after 22 iterations. Use EP: True
# Iteration 100: Agents have selected goals [4, 0, 1, 0, 2]. Execution Time: 0.25600314140319824s Agents did not converge to the same goal within the maximum iterations.
# Iteration 21: Agents have selected goals [0, 1]. Execution Time: 0.008032083511352539s Agents have converged to Goal 0 after 21 iterations. Use EP: False
# Iteration 15: Agents have selected goals [1, 2, 0]. Execution Time: 0.013998031616210938s Agents have converged to Goal 1 after 15 iterations. Use EP: False
# Iteration 22: Agents have selected goals [3, 2, 0, 1]. Execution Time: 0.02100062370300293s Agents have converged to Goal 3 after 22 iterations. Use EP: False
# Iteration 100: Agents have selected goals [0, 0, 0, 0, 0]. Execution Time: 0.0380251407623291s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  90.0 %-------------------
# Iteration 100: Agents have selected goals [1, 1]. Execution Time: 0.0009970664978027344s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 0, 0]. Execution Time: 0.0009999275207519531s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [0, 3, 1, 0]. Execution Time: 0.002996683120727539s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [4, 1, 4, 1, 1]. Execution Time: 0.006000041961669922s Agents did not converge to the same goal within the maximum iterations.
# Iteration 30: Agents have selected goals [0, 1]. Execution Time: 0.01399993896484375s Agents have converged to Goal 0 after 30 iterations. Use EP: True
# Iteration 69: Agents have selected goals [1, 0, 2]. Execution Time: 0.038001298904418945s Agents have converged to Goal 1 after 69 iterations. Use EP: True
# Iteration 35: Agents have selected goals [2, 3, 1, 0]. Execution Time: 0.07400012016296387s Agents have converged to Goal 2 after 35 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 2, 4, 3, 0]. Execution Time: 0.2508111000061035s Agents did not converge to the same goal within the maximum iterations.
# Iteration 23: Agents have selected goals [0, 1]. Execution Time: 0.008074283599853516s Agents have converged to Goal 0 after 23 iterations. Use EP: False
# Iteration 68: Agents have selected goals [1, 0, 2]. Execution Time: 0.016000032424926758s Agents have converged to Goal 1 after 68 iterations. Use EP: False
# Iteration 100: Agents have selected goals [0, 3, 1, 1]. Execution Time: 0.021971940994262695s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 2, 1, 3, 4]. Execution Time: 0.0390169620513916s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  92.0 %-------------------
# Iteration 100: Agents have selected goals [1, 1]. Execution Time: 0.0009889602661132812s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 1, 1]. Execution Time: 0.0020012855529785156s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 3, 3, 1]. Execution Time: 0.00310516357421875s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [4, 3, 4, 0, 3]. Execution Time: 0.005997419357299805s Agents did not converge to the same goal within the maximum iterations.
# Iteration 24: Agents have selected goals [0, 1]. Execution Time: 0.015029668807983398s Agents have converged to Goal 0 after 24 iterations. Use EP: True
# Iteration 47: Agents have selected goals [2, 1, 0]. Execution Time: 0.03391671180725098s Agents have converged to Goal 2 after 47 iterations. Use EP: True
# Iteration 36: Agents have selected goals [1, 2, 0, 3]. Execution Time: 0.07388472557067871s Agents have converged to Goal 1 after 36 iterations. Use EP: True
# Iteration 30: Agents have selected goals [4, 2, 1, 0, 3]. Execution Time: 0.25200772285461426s Agents have converged to Goal 4 after 30 iterations. Use EP: True
# Iteration 24: Agents have selected goals [0, 1]. Execution Time: 0.007001399993896484s Agents have converged to Goal 0 after 24 iterations. Use EP: False
# Iteration 100: Agents have selected goals [2, 2, 2]. Execution Time: 0.015000104904174805s Agents did not converge to the same goal within the maximum iterations.
# Iteration 36: Agents have selected goals [1, 2, 0, 3]. Execution Time: 0.021000146865844727s Agents have converged to Goal 1 after 36 iterations. Use EP: False
# Iteration 100: Agents have selected goals [4, 3, 3, 3, 0]. Execution Time: 0.03799772262573242s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  94.0 %-------------------
# Iteration 100: Agents have selected goals [1, 1]. Execution Time: 0.001004934310913086s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 2, 1]. Execution Time: 0.0010001659393310547s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 1, 0, 1]. Execution Time: 0.003915309906005859s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [1, 4, 4, 1, 1]. Execution Time: 0.005998849868774414s Agents did not converge to the same goal within the maximum iterations.
# Iteration 53: Agents have selected goals [1, 0]. Execution Time: 0.013999700546264648s Agents have converged to Goal 1 after 53 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 0, 1]. Execution Time: 0.03290367126464844s Agents did not converge to the same goal within the maximum iterations.
# Iteration 20: Agents have selected goals [2, 1, 0, 3]. Execution Time: 0.07601332664489746s Agents have converged to Goal 2 after 20 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 0, 3, 1, 0]. Execution Time: 0.255002498626709s Agents did not converge to the same goal within the maximum iterations.
# Iteration 53: Agents have selected goals [1, 0]. Execution Time: 0.007032871246337891s Agents have converged to Goal 1 after 53 iterations. Use EP: False
# Iteration 100: Agents have selected goals [1, 0, 1]. Execution Time: 0.019022464752197266s Agents did not converge to the same goal within the maximum iterations.
# Iteration 22: Agents have selected goals [2, 1, 0, 3]. Execution Time: 0.020995378494262695s Agents have converged to Goal 2 after 22 iterations. Use EP: False
# Iteration 100: Agents have selected goals [0, 1, 3, 0, 0]. Execution Time: 0.038964033126831055s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  96.0 %-------------------
# Iteration 14: Agents have selected goals [1, 0]. Execution Time: 0.0009963512420654297s Agents have converged to Goal 1 after 14 iterations. Use EP: True
# Iteration 10: Agents have selected goals [0, 1, 2]. Execution Time: 0.0010004043579101562s Agents have converged to Goal 0 after 10 iterations. Use EP: True
# Iteration 100: Agents have selected goals [1, 2, 2, 3]. Execution Time: 0.003000497817993164s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [2, 4, 3, 3, 0]. Execution Time: 0.00599980354309082s Agents did not converge to the same goal within the maximum iterations.
# Iteration 14: Agents have selected goals [1, 0]. Execution Time: 0.014998435974121094s Agents have converged to Goal 1 after 14 iterations. Use EP: True
# Iteration 11: Agents have selected goals [0, 1, 2]. Execution Time: 0.03500008583068848s Agents have converged to Goal 0 after 11 iterations. Use EP: True
# Iteration 25: Agents have selected goals [1, 2, 0, 3]. Execution Time: 0.07400083541870117s Agents have converged to Goal 1 after 25 iterations. Use EP: True
# Iteration 100: Agents have selected goals [3, 3, 3, 3, 0]. Execution Time: 0.25499916076660156s Agents did not converge to the same goal within the maximum iterations.
# Iteration 14: Agents have selected goals [1, 0]. Execution Time: 0.008001089096069336s Agents have converged to Goal 1 after 14 iterations. Use EP: False
# Iteration 11: Agents have selected goals [0, 1, 2]. Execution Time: 0.014059305191040039s Agents have converged to Goal 0 after 11 iterations. Use EP: False
# Iteration 100: Agents have selected goals [1, 2, 2, 3]. Execution Time: 0.02099895477294922s Agents did not converge to the same goal within the maximum iterations.
# Iteration 100: Agents have selected goals [4, 4, 4, 4, 4]. Execution Time: 0.03891134262084961s Agents did not converge to the same goal within the maximum iterations.
# -------------------
# Percentage Complete:  98.0 %-------------------

# %%
energy_results, ending_energy = aif.parse_free_energy_scores(avg_nrg_over_time, num_frames)
aif.plot_energy(energy_results, num_agents)

# %%
# Calculate distance to final goals
final_distances = np.zeros((num_agents, goals.shape[0]))
for i in range(num_agents):
    for j in range(goals.shape[0]):
        final_distances[i,j] = np.linalg.norm(final_positions[i,:2] - goals[j,:])
print("Final distances: ", final_distances)
# Out:
# Final distances:  [[0.02488646 9.98047395]
#  [0.03748569 9.97078675]
#  [0.09155599 9.99940493]]

# %%
# Scratch code for testing

goals = np.array([[0,0],[0.,10.]])
my_pose = np.array([14.12709979, 12.76192634,  0.])
other_pose = np.array([6.30305407,  7.28140647,  0.])
saliences = np.zeros(goals.shape[0])
goal_azimuths = np.arctan2(goals[:, 1] - my_pose[1], goals[:, 0] - my_pose[0])
observed_azimuth = np.arctan2(other_pose[1] - my_pose[1], other_pose[0] - my_pose[0])
relative_azimuths = np.abs((goal_azimuths - observed_azimuth + np.pi) % (2 * np.pi) - np.pi)
azimuth_salience = 1./8 * np.exp(- relative_azimuths / np.pi)  # normalize and invert to make smaller angles more salient
saliences += azimuth_salience
# Compute if observed robot is heading towards the goal
# heading_to_goal = (np.arctan2(goals[:, 1] - observation['position'][1], goals[:, 0] - observation['position'][0]) - observation['heading'] + np.pi) % (2 * np.pi) - np.pi
# heading_salience = 1./8 * np.exp(- np.abs(heading_to_goal) / np.pi)
# saliences += heading_salience


print("Goal Azimuth: ", goal_azimuths)
print("Relative Azimuth: ", azimuth_salience)
print("Observed Azimuth: ", observed_azimuth)
print("Salience: ", saliences)
# print("Heading Salience: ", heading_salience)
print(np.exp(0.8/np.pi))
# Out:
# Goal Azimuth:  [-2.40692159 -2.9485224 ]
# Relative Azimuth:  [0.1201765  0.10942825]
# Observed Azimuth:  -2.5305504167886905
# Salience:  [0.1201765  0.10942825]
# 1.2900073408606396
